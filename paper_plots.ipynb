# %%
#!pip install numpy pandas scipy matplotlib

# %%
import numpy             as np
import matplotlib.pyplot as plt
import pandas            as pd 
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)

# %%
sd_jwt_color = '#B84631'
hmac_color = '#EB9FC0'
merkle_color = '#F7B660'
monoclaim_color = '#AE9ED4'
bbs_plus_color = '#666666'
ps_color = '#7C9DC7'
cl_color = '#B2C6CD'
clpok_color = '#BE9D75'

# %%
sd_jwt_marker = 'D'
hmac_marker = 's'
merkle_marker = 'o'
monoclaim_marker = '*'
bbs_plus_marker = 'x'
ps_marker = 'v'
cl_marker = 'p'
clpok_marker = '.'

marker_range_10 = range(0,10,1)
marker_range_100 = range(0,100,10)

# %%
df = pd.read_csv("csv/vc_issuance_duration.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
window_size = 100
x = range(1,101,1)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_100)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_100)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_100)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_100)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_100)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_100)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_100)

# Set tight layout for figure
plt.tight_layout()

# Set the y-axis to logarithmic scale (base 10)
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(10))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))

# Add labels and title
ax.set_xlabel("Number of Claims")
ax.set_ylabel("Latency (us)")

# Turn grid on 
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper left', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(0, 100)
plt.ylim(1e1, 1e5)

# Show figure and save it for paper
plt.savefig("VC Generation Time.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#      SDJWT  HMAC  Merkle  Monoclaim  BBSPlus   PS     CL
# 0      31    32      30         28     1055  914   1512
# 1      31    35      30         42     1435  901   1801
# 2      32    37      30         57     1818  913   2077
# 3      33    40      31         70     2198  909   2388
# 4      34    43      31         85     2583  908   2671
# ..    ...   ...     ...        ...      ...  ...    ...
# 95     78   270      59       1341    37333  919  29709
# 96     79   271      59       1356    37708  918  29975
# 97     79   274      59       1368    38106  955  30271
# 98     79   277      60       1383    38478  926  30569
# 99     80   280      60       1401    38857  927  30908
#
# [100 rows x 7 columns]

# %%
df = pd.read_csv("csv/vc_jwt_length.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(1,101,1)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_100)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_100)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_100)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_100)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_100)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_100)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_100)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title 
ax.set_xlabel("Number of Claims")
ax.set_ylabel("Size (Byte)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(10))
# ax.yaxis.set_major_locator(MultipleLocator(5000))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# Turn grid on 
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper left', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(0, 100)
plt.ylim(1e2, 1e5)

# Show figure and save it for paper
plt.savefig("VC Size.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#      SDJWT   HMAC  Merkle  Monoclaim  BBSPlus    PS     CL
# 0     711    829     788        393      555  1488   1791
# 1     849   1109     821        555      595  1527   2211
# 2     999   1376     873        716      635  1563   2636
# 3    1149   1645     911        877      675  1600   3055
# 4    1301   1919     949       1039      715  1621   3476
# ..    ...    ...     ...        ...      ...   ...    ...
# 95  14999  26896    4823      15952     4587  5521  42087
# 96  15157  27164    4860      16116     4629  5559  42567
# 97  15311  27464    4901      16280     4672  5609  42991
# 98  15444  27735    4952      16444     4715  5631  43407
# 99  15619  28063    4989      16611     4760  5680  43832
#
# [100 rows x 7 columns]

# %%
df = pd.read_csv("csv/vc_verification_duration.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(1,101,1)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_100)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_100)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_100)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_100)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_100)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_100)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_100)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Claims")
ax.set_ylabel("Latency (us)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(10))
# ax.yaxis.set_major_locator(MultipleLocator(10000))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper left', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(0, 100)
plt.ylim(1e1, 1e5)

# Show figure and save it for paper
plt.savefig("VC Verification Time.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#      SDJWT  HMAC  Merkle  Monoclaim  BBSPlus     PS    CL
# 0      48    50      49         47     2377   2332   511
# 1      49    53      49         87     2758   2443   581
# 2      49    55      49        127     3141   2560   649
# 3      50    57      50        167     3522   2666   717
# 4      50    60      50        206     3902   2779   782
# ..    ...   ...     ...        ...      ...    ...   ...
# 95     88   275      75       3808    38651  12779  7365
# 96     88   278      75       3850    39040  12881  7477
# 97     89   282      75       3891    39421  12997  7555
# 98     90   283      76       3930    39806  13101  7624
# 99     92   286      76       3969    40183  13215  7707
#
# [100 rows x 7 columns]

# %%
df = pd.read_csv("csv/10_vp_issuance_duration.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(1,11,1)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_10)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_10)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_10)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_10)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_10)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_10)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_10)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Disclosed Claims")
ax.set_ylabel("Latency (us)")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(1))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
ax.set_yscale("log")

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper left', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(1, 10)
plt.ylim(1e1, 1e6)

# Show figure and save it for paper
plt.savefig("10 VP Issuance Time.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#     SDJWT  HMAC  Merkle  Monoclaim  BBSPlus    PS      CL
# 0     33    33      36         30     7597  3143  116827
# 1     32    33      36         31     7413  3757  105859
# 2     33    33      36         31     7221  4164   94829
# 3     33    34      36         32     7035  4388   83822
# 4     33    34      37         32     6853  4394   72791
# 5     33    34      36         33     6665  4211   61796
# 6     33    34      37         33     6474  3814   50794
# 7     34    35      37         34     6290  3243   39817
# 8     34    35      37         34     6106  2402   28770
# 9     34    35      37         35     5921  1357   17758

# %%
df = pd.read_csv("csv/10_vp_jwt_length.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(1,11,1)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_10)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_10)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_10)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_10)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_10)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_10)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_10)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Disclosed Claims")
ax.set_ylabel("Size (Byte)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(1))
# ax.yaxis.set_major_locator(MultipleLocator(1000))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper left', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(1, 10)
plt.ylim(1e2, 1e6)

# Show figure and save it for paper
plt.savefig("10 VP Size.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#     SDJWT  HMAC  Merkle  Monoclaim  BBSPlus    PS      CL
# 0   1366  1492    1543        480     2298  1802  129540
# 1   1450  1696    1434        642     2250  1832  117528
# 2   1534  1907    1476        803     2186  1883  105599
# 3   1618  2116    1370        964     2140  1934   93652
# 4   1702  2316    1564       1126     2095  1967   81691
# 5   1786  2523    1452       1287     2058  2011   69728
# 6   1870  2730    1490       1448     2008  2051   57767
# 7   1954  2940    1386       1610     1955  2098   45818
# 8   2038  3151    1416       1771     1903  2143   33856
# 9   2124  3359    1316       1935     1855  2182   21900

# %%
df = pd.read_csv("csv/10_vp_verification_duration.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(1,11,1)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_10)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_10)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_10)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_10)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_10)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_10)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_10)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Disclosed Claims")
ax.set_ylabel("Latency (us)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(1))
# ax.yaxis.set_major_locator(MultipleLocator(1000))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper left', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(1, 10)
plt.ylim(1e1, 1e5)

# Show figure and save it for paper
plt.savefig("10 VP Verification Time.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#     SDJWT  HMAC  Merkle  Monoclaim  BBSPlus    PS     CL
# 0    102   104     102         97     6468  3099  59161
# 1    102   106     102        137     6465  3209  53807
# 2    102   108     102        177     6465  3330  48453
# 3    103   111     102        217     6470  3435  43137
# 4    103   113     103        257     6468  3550  37818
# 5    103   115     102        297     6470  3658  32585
# 6    103   118     103        338     6475  3765  27181
# 7    103   121     103        378     6468  3879  21858
# 8    104   123     103        418     6466  3992  16489
# 9    104   126     103        458     6469  4111  11188

# %%
df = pd.read_csv("csv/100_vp_issuance_duration.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(10,101,10)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_10)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_10)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_10)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_10)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_10)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_10)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_10)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Disclosed Claims")
ax.set_ylabel("Latency (us)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(10))
# ax.yaxis.set_major_locator(MultipleLocator(100000))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper left', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(10, 100)
plt.ylim(1e1, 1e7)

# Show figure and save it for paper
plt.savefig("100 VP Issuance Time.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#     SDJWT  HMAC  Merkle  Monoclaim  BBSPlus      PS       CL
# 0     50    50      57         39    58768   21447  1127291
# 1     52    53      59         44    56920  109821  1016991
# 2     55    58      62         48    55052  177874   906883
# 3     57    62      63         52    53183  225727   796922
# 4     60    66      66         57    51314  253009   686755
# 5     63    69      67         61    49451  260789   576783
# 6     65    73      71         65    47580  247650   466745
# 7     67    77      74         70    45716  213462   356692
# 8     69    80      77         76    43861  160213   246459
# 9     71    83      80         80    41985   86440   136501

# %%
df = pd.read_csv("csv/100_vp_jwt_length.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(10,101,10)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_10)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_10)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_10)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_10)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_10)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_10)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_10)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Disclosed Claims")
ax.set_ylabel("Size (Bytes)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(10))
# ax.yaxis.set_major_locator(MultipleLocator(10000))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper right', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(10, 100)
plt.ylim(1e2, 1e7)

# Show figure and save it for paper
plt.savefig("100 VP Size.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#     SDJWT   HMAC  Merkle  Monoclaim  BBSPlus    PS       CL
# 0   7144   7254    1996        480    10575  1776  1244506
# 1   7990   9346    2127       2099    10092  2228  1124824
# 2   8856  11440    2602       3739     9642  2696  1005271
# 3   9723  13551    2756       5379     9167  3159   885466
# 4  10590  15671    3531       7019     8734  3622   765847
# 5  11456  17798    3839       8659     8284  4095   646323
# 6  12323  19914    4147      10299     7820  4558   526687
# 7  13190  22030    4795      11939     7370  5023   407010
# 8  14056  24122    5418      13579     6919  5492   287434
# 9  14923  26243    5568      15219     6458  5960   167804

# %%
df = pd.read_csv("csv/100_vp_verification_duration.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(10,101,10)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_10)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_10)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_10)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_10)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_10)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_10)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_10)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Disclosed Claims")
ax.set_ylabel("Latency (us)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(10))
# ax.yaxis.set_major_locator(MultipleLocator(10000))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper right', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(10, 100)
plt.ylim(1e1, 1e6)

# Show figure and save it for paper
plt.savefig("100 VP Verification Time.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#     SDJWT  HMAC  Merkle  Monoclaim  BBSPlus     PS      CL
# 0    115   118     103         97    40806   3102  563205
# 1    118   142     106        498    40813   4218  510075
# 2    122   165     111        898    40821   5327  456876
# 3    126   189     114       1299    40828   6418  403476
# 4    129   214     119       1698    40832   7525  350210
# 5    133   238     121       2100    40825   8611  296963
# 6    138   263     125       2497    40836   9717  243696
# 7    142   287     130       2897    40850  10828  190591
# 8    146   313     134       3300    40851  11915  137219
# 9    150   339     136       3702    40842  13009   83828

# %%
df = pd.read_csv("csv/initialization_duration.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(1,101,1)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_100)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_100)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_100)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_100)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_100)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_100)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_100)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Claims")
ax.set_ylabel("Latency (us)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(10))
# ax.yaxis.set_major_locator(MultipleLocator(1e6))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(10))

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper right', fancybox=True, framealpha=0.8, prop={'size': 8})

# Set axis range
plt.xlim(0, 100)
plt.ylim(1, 1e7)

# Show figure and save it for paper
plt.savefig("Keygen Time.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#      SDJWT  HMAC  Merkle  Monoclaim  BBSPlus       PS      CL
# 0       3     3       3          3      547      497  632725
# 1       3     3       3          3      547     1310  587853
# 2       3     3       3          3      549     2536  606903
# 3       4     3       3          3      547     4169  566421
# 4       3     3       3          3      547     6225  601155
# ..    ...   ...     ...        ...      ...      ...     ...
# 95      3     3       3          3      545  1855145  655872
# 96      3     3       3          3      546  1893977  605645
# 97      3     3       3          3      546  1932112  638313
# 98      3     3       3          3      546  1972456  618797
# 99      3     3       3          3      545  2012524  623141
#
# [100 rows x 7 columns]

# %%
df = pd.read_csv("csv/issuer_keypair_length.csv")
print("Contents in csv file:\n", df)

fig, ax = plt.subplots()
x = range(1,101,1)

# Plot the data
ax.plot(x, df['SDJWT'], label='SDJWT', color=sd_jwt_color, marker=sd_jwt_marker, markevery=marker_range_100)
ax.plot(x, df['HMAC'], label='HMAC', color=hmac_color, marker=hmac_marker, markevery=marker_range_100)
ax.plot(x, df['Merkle'], label='Merkle', color=merkle_color, marker=merkle_marker, markevery=marker_range_100)
ax.plot(x, df['Monoclaim'], label='Monoclaim', color=monoclaim_color, marker=monoclaim_marker, markevery=marker_range_100)
ax.plot(x, df['BBSPlus'], label='BBS+', color=bbs_plus_color, marker=bbs_plus_marker, markevery=marker_range_100)
ax.plot(x, df['PS'], label='PS', color=ps_color, marker=ps_marker, markevery=marker_range_100)
ax.plot(x, df['CL'], label='CL', color=cl_color, marker=cl_marker, markevery=marker_range_100)

# Set tight layout for figure
plt.tight_layout()

# Add labels and title
ax.set_xlabel("Number of Claims")
ax.set_ylabel("Size (Bytes)")
ax.set_yscale("log")

# Change major ticks
ax.xaxis.set_major_locator(MultipleLocator(10))
# ax.yaxis.set_major_locator(MultipleLocator(2e5))

# Change minor ticks
ax.xaxis.set_minor_locator(AutoMinorLocator(10))
# ax.yaxis.set_minor_locator(AutoMinorLocator(1))

# Turn grid on
ax.grid(which='major', color='#EEEEEE', linestyle='solid')
ax.grid(which='minor', color='#EEEEEE', linestyle='solid')

# Add legend
ax.legend(loc='upper left', fancybox=True, framealpha=0.4, prop={'size': 9})

# Set axis range
plt.xlim(0, 100)
plt.ylim(1e2, 1e7)

# Show figure and save it for paper
plt.savefig("Keygen Size.pdf", dpi=1000, format='pdf', bbox_inches='tight')
plt.show()
# Out:
# Contents in csv file:
#      SDJWT  HMAC  Merkle  Monoclaim  BBSPlus       PS    CL
# 0    1340  1340    1340       1340      260     1588  1169
# 1    1340  1340    1340       1340      260     2706  1169
# 2    1340  1340    1340       1340      260     4115  1171
# 3    1340  1340    1340       1340      260     5862  1168
# 4    1340  1340    1340       1340      260     8006  1168
# ..    ...   ...     ...        ...      ...      ...   ...
# 95   1340  1340    1340       1340      260  1639351  1170
# 96   1340  1340    1340       1340      260  1672511  1169
# 97   1340  1340    1340       1340      260  1706309  1170
# 98   1340  1340    1340       1340      260  1741393  1169
# 99   1340  1340    1340       1340      260  1775898  1169
#
# [100 rows x 7 columns]
